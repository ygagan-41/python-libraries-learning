# %%
import numpy as np
import pandas as pd

# %%
labels = ['a','b','c']
lst = [1,2,3]
arr = np.array([10,20,30])
dict = {
    1:10,
    2:20,
    3:30
}

# %%
pd.Series(lst)
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
pd.Series(arr , index = labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(dict)
# Out:
# 1    10
# 2    20
# 3    30
# dtype: int64
